# %%
# !git clone https://github.com/Gombessa1938/Bull-Sperm-morphology-with-YOLO.git
# %cd Bull-Sperm-morphology-with-YOLO
# Out:
# Cloning into 'Bull-Sperm-morphology-with-YOLO'...
# remote: Enumerating objects: 182, done.
# remote: Counting objects: 100% (182/182), done.
# remote: Compressing objects: 100% (178/178), done.
# remote: Total 182 (delta 53), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (182/182), 1.33 MiB | 4.20 MiB/s, done.
# Resolving deltas: 100% (53/53), done.
# /content/Bull-Sperm-morphology-with-YOLO
#      |████████████████████████████████| 636 kB 8.2 MB/s

# %%
# %pip install -qr requirements.txt

# %%
# !python detect.py --weights ../trained_weight.pt --img 416 --conf 0.5 --source ../test_img.jpg
# Out:
# detect: weights=['../trained_weight.pt'], source=../test_img.jpg, imgsz=[416, 416], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, tfl_int8=False
# YOLOv5 🚀 2ceb17e torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 476 layers, 87225610 parameters, 0 gradients, 217.2 GFLOPs
# image 1/1 /content/Bull-Sperm-morphology-with-YOLO/../test_img.jpg: 416x416 1 Teratoid, Done. (0.067s)
# Results saved to runs/detect/exp5
# Done. (0.114s)

# %%
from google.colab.patches import cv2_imshow,cv2
img = cv2.imread("/content/Bull-Sperm-morphology-with-YOLO/runs/detect/exp5/test_img.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=416x416 at 0x7FA872479410>
